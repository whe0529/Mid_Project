# %% [markdown]
# <a href="https://colab.research.google.com/github/whe0529/Mid_Project/blob/main/train_volleyball.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content
# !git clone https://github.com/ultralytics/yolov5
# Out:
# /content
# Cloning into 'yolov5'...
# remote: Enumerating objects: 16057, done.
# remote: Total 16057 (delta 0), reused 0 (delta 0), pack-reused 16057
# Receiving objects: 100% (16057/16057), 14.66 MiB | 12.71 MiB/s, done.
# Resolving deltas: 100% (11028/11028), done.

# %%
# %cd /content/yolov5/
# !pip install -r requirements.txt
# Out:
# /content/yolov5
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="B7UmtAK7ebyQZFGJwz39")
project = rf.workspace("vod2-yosi").project("bola-voli")
dataset = project.version(1).download("yolov5")
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.3/63.3 kB 2.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 9.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 8.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 18.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 9.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.2/72.2 kB 8.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 6.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.1.1
#     Uninstalling pyparsing-3.1.1:
#       Successfully uninstalled pyparsing-3.1.1
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.8.1.78
#     Uninstalling opencv-python-headless-4.8.1.78:
#       Successfully uninstalled opencv-python-headless-4.8.1.78
# ...

# %%
# %cd /content/yolov5/

# !python train.py
# Out:
# /content/yolov5
# 2023-11-07 12:39:20.614610: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-07 12:39:20.614676: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-07 12:39:20.614713: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
#!pip uninstall opencv-python
#!pip install opencv-python
# !python detect.py --weights runs/train/exp/weights/best.pt --source "https://youtu.be/V4Z5z2pKMvA" --conf 0.7
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# 0: 384x640 10 persons, 7.3ms
# 0: 384x640 10 persons, 7.3ms
# 0: 384x640 10 persons, 7.5ms
# 0: 384x640 10 persons, 9.1ms
# 0: 384x640 8 persons, 7.3ms
# 0: 384x640 8 persons, 7.5ms
# 0: 384x640 8 persons, 7.4ms
# 0: 384x640 8 persons, 7.9ms
# 0: 384x640 8 persons, 9.0ms
# 0: 384x640 8 persons, 7.7ms
# 0: 384x640 8 persons, 7.4ms
# 0: 384x640 8 persons, 7.7ms
# 0: 384x640 8 persons, 7.3ms
# 0: 384x640 8 persons, 7.6ms
# 0: 384x640 8 persons, 7.6ms
# 0: 384x640 8 persons, 8.2ms
# 0: 384x640 8 persons, 7.6ms
# 0: 384x640 8 persons, 7.6ms
# 0: 384x640 8 persons, 7.6ms
# 0: 384x640 8 persons, 7.4ms
# 0: 384x640 8 persons, 7.4ms
# 0: 384x640 8 persons, 7.5ms
# 0: 384x640 8 persons, 9.1ms
# 0: 384x640 8 persons, 13.3ms
# 0: 384x640 10 persons, 7.7ms
# 0: 384x640 10 persons, 8.8ms
# 0: 384x640 10 persons, 10.7ms
# 0: 384x640 10 persons, 8.6ms
# 0: 384x640 10 persons, 7.6ms
# 0: 384x640 10 persons, 9.2ms
# 0: 384x640 10 persons, 7.9ms
# ...

# %%
# !python detect.py --weights runs/train/exp/weights/best.pt --source "https://youtu.be/in8-3u1Es4I" --conf 0.7
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# 0: 384x640 (no detections), 5.4ms
# 0: 384x640 (no detections), 7.2ms
# 0: 384x640 1 person, 5.5ms
# 0: 384x640 1 person, 5.4ms
# 0: 384x640 1 person, 7.4ms
# 0: 384x640 1 person, 5.7ms
# 0: 384x640 1 person, 5.4ms
# 0: 384x640 1 person, 5.4ms
# 0: 384x640 1 person, 5.5ms
# 0: 384x640 1 person, 5.7ms
# 0: 384x640 1 person, 5.5ms
# 0: 384x640 1 person, 10.2ms
# 0: 384x640 (no detections), 5.5ms
# 0: 384x640 (no detections), 5.7ms
# 0: 384x640 (no detections), 5.5ms
# 0: 384x640 (no detections), 5.5ms
# 0: 384x640 (no detections), 5.4ms
# 0: 384x640 (no detections), 5.4ms
# 0: 384x640 (no detections), 6.0ms
# 0: 384x640 (no detections), 5.4ms
# 0: 384x640 (no detections), 5.5ms
# 0: 384x640 (no detections), 5.7ms
# 0: 384x640 (no detections), 6.0ms
# 0: 384x640 (no detections), 5.5ms
# 0: 384x640 (no detections), 5.7ms
# 0: 384x640 (no detections), 5.4ms
# 0: 384x640 (no detections), 12.3ms
# 0: 384x640 (no detections), 8.9ms
# ...

# %%
# !pip install colab-ssh --upgrade

from colab_ssh import launch_ssh_cloudflared, init_git_cloudflared
launch_ssh_cloudflared(password='0000')
# Out:
# ...
# <style>
# *{
# 	outline:none;
# }
# code{
# 	display:inline-block;
# 	padding:5px 10px;
# 	background: #444;
# 	border-radius: 4px;
# 	white-space: pre-wrap;
# 	position:relative;
# 	color:white;
# }
# .copy-code-button{
# 	float:right;
# 	background:#333;
# 	color:white;
# 	border: none;
# 	margin: 0 0 0 10px;
# 	cursor: pointer;
# }
# p, li{
# 	max-width:700px;
# }
# .choices{
# 	display:flex;
# 	flex: 1 0 auto;
# }
# .choice-section{
# 	border:solid 1px #555;
# 	border-radius: 4px;
# 	min-width:300px;
# 	margin: 10px 15px 0 0;
# 	padding: 0 15px 15px 15px ;
# }
# .button{
# 	padding: 10px 15px;
# 	background:#333;
# 	border-radius: 4px;
# 	border:solid 1px #555;
# 	color:white;
# 	font-weight:bold;
# 	cursor:pointer;
# }
# .pill{
# 	padding:2px 4px;
# 	border-radius: 100px;
# 	background-color:#e65858;
# 	font-size:12px;
# 	font-weight:bold;
# 	margin: 0 15px;
# 	color:white;
# }
# </style>
# <details class="choice-section">
# 	<summary style="cursor:pointer">
# ...
